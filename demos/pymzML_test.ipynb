# %%
import pyopenms as oms
import matplotlib.pyplot as plt
# Out:
# Determination of memory status is not supported on this
#  platform, measuring for memoryleaks will never fail

# %%
exp = oms.MSExperiment()
oms.MzMLFile().load("/Users/mitchsyberg-olsen/Library/CloudStorage/Box-Box/lab/data/2025/09/2025-09-16_D4_variants_MALDI/2025_09_22_0001.mzml", exp)

# %%
exp.getNrSpectra()
# Out:
# 50

# %%
spectrum = exp.getSpectrum(1)
name = spectrum.getName()
id = spectrum.getNativeID()
print(f"spectrum.getName result: {name}")
print(f"spectrum.getNativeID result: {id}")
# x = spectrum.metaRegistry()
# print(x)
# Out:
# spectrum.getName result:
# spectrum.getNativeID result: scan=2 file=sourceFile

# %%
x = exp.getSpectrum(0).get_peaks()[0]
y = exp.getSpectrum(0).get_peaks()[1]

plt.plot(x,y)
plt.show()

# %%
spectrum = 2

x = exp.getSpectrum(spectrum).get_peaks()[0]
y = exp.getSpectrum(spectrum).get_peaks()[1]

start = 485300
end = 486500

plt.plot(x[start:end],y[start:end])
plt.show()

# %%
# exp_filtered = oms.MSExperiment()
# oms.MzMLFile().load("/Users/mitchsyberg-olsen/Library/CloudStorage/Box-Box/lab/data/2025/09/2025-09-16_D4_variants_MALDI/2025_09_22_0001.mzml", exp_filtered)
#
# gf = oms.GaussFilter()
# param = gf.getParameters()
# param.setValue("gaussian_width", 1.0)  # needs wider width
# gf.setParameters(param)
# gf.filterExperiment(exp_filtered)

# %%
# spectrum = 2
#
# x = exp_filtered.getSpectrum(spectrum).get_peaks()[0]
# y = exp_filtered.getSpectrum(spectrum).get_peaks()[1]
#
# start = 482300
# end = 508500
#
# plt.plot(x[start:end],y[start:end])
# plt.show()

# %%
# start = 485000
# end = 490500
#
# plt.plot(x[start:end],y[start:end])
# plt.show()
