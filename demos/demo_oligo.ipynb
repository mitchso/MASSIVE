# %% [markdown]
# Import Oligo object

# %%
from oligo_maldi.oligo import Oligo

# %% [markdown]
# Define oligos

# %%
demo_oligo = Oligo(name='Demo Oligo', seq='GAAAGACCACAACG', five_prime_end='OH')

# %% [markdown]
# Below are various useful Oligo methods

# %%
demo_oligo.composition
# Out:
# {'C': 136, 'H': 169, 'N': 62, 'O': 75, 'P': 13, 'S': 0}

# %%
demo_oligo.monoisotopic_mass
# Out:
# 4273.798

# %%
demo_oligo.average_mass
# Out:
# 4275.839

# %%
demo_oligo.isotopic_distribution
# Out:
# [Peak(mz=4273.797793, intensity=0.150915, charge=1),
#  Peak(mz=4274.800374, intensity=0.263414, charge=1),
#  Peak(mz=4275.802866, intensity=0.251884, charge=1),
#  Peak(mz=4276.805309, intensity=0.172145, charge=1),
#  Peak(mz=4277.807717, intensity=0.093450, charge=1),
#  Peak(mz=4278.810100, intensity=0.042625, charge=1),
#  Peak(mz=4279.812463, intensity=0.016913, charge=1),
#  Peak(mz=4280.814809, intensity=0.005977, charge=1),
#  Peak(mz=4281.817142, intensity=0.001913, charge=1),
#  Peak(mz=4282.819464, intensity=0.000562, charge=1),
#  Peak(mz=4283.821775, intensity=0.000153, charge=1),
#  Peak(mz=4284.824078, intensity=0.000039, charge=1),
#  Peak(mz=4285.826373, intensity=0.000009, charge=1),
#  Peak(mz=4286.828661, intensity=0.000002, charge=1),
#  Peak(mz=4287.830943, intensity=0.000000, charge=1),
#  Peak(mz=4288.833220, intensity=0.000000, charge=1),
#  Peak(mz=4289.835492, intensity=0.000000, charge=1),
#  Peak(mz=4290.837759, intensity=0.000000, charge=1),
#  Peak(mz=4291.840022, intensity=0.000000, charge=1),
#  Peak(mz=4292.842281, intensity=0.000000, charge=1)]

# %%
str(demo_oligo)
# Out:
# "5' (HO)-GAAAGACCACAACG 3'"

# %%
demo_oligo.iso_dist_plot()
# Out:
# (<Figure size 800x300 with 1 Axes>,
#  <Axes: title={'left': 'Demo Oligo'}, xlabel='m/z', ylabel='Intensity (au)'>)

# %% [markdown]
# Integrate Oligo object into loops

# %%
ends = ['P', 'PP', 'PPP']

for end in ends:
    o = Oligo(name='tmp', seq='TGGGAGACCACAACG', five_prime_end=end)
    print(o.monoisotopic_mass)
# Out:
# 4689.8
# 4769.766
# 4849.733
# 2978.538
