# %% [markdown]
# Import Oligo object

# %%
from oligo_maldi.oligo import Oligo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from oligo_maldi.oligo import Oligo
#
# File ~/github/oligo_maldi/oligo_maldi/oligo.py:1
# ----> 1 import matplotlib.pyplot as plt
#       2 from brainpy import isotopic_variants
#       4 class Oligo:
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Define oligos

# %%
demo_oligo = Oligo(name='Demo Oligo', seq='GAAAGACCACAACG', five_prime_end='OH')
